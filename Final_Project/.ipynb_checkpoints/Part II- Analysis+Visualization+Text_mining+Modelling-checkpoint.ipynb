# %% [markdown]
# # Data Analysis & Visualization

# %% [markdown]
# If you want to hide all code cells, please click the Toggle Code button below :)

# %%
from IPython.display import display_html
display_html("""<button onclick="$('.input, .output_stderr, .output_error').toggle();">Toggle Code</button>""", raw=True)
# Out:
# <button onclick="$('.input, .output_stderr, .output_error').toggle();">Toggle Code</button>

# %%
import numpy as np
import pandas as pd
import scipy
import datetime
import seaborn as sns
import os
import matplotlib.pyplot as plt
import nltk
from wordcloud import WordCloud, STOPWORDS
from scipy.misc import imread
import imageio
# %matplotlib inline

import time
import csv
from nltk.corpus import PlaintextCorpusReader
from nltk import sent_tokenize,word_tokenize 
from nltk.book import *
import gensim.summarization
plt.style.use('fivethirtyeight')

from scipy.misc import imread
sns.set(color_codes=True)
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# ## Load data

# %% [markdown]
# Load data from cleaned_data.csv. Check the Part I notebook for more preprocessing details.
#
# This dataset includes over 1800 entries of top movie records.
#
# Below is an example.

# %%
df = pd.read_csv('cleaned_data.csv', index_col='Unnamed: 0')

# %%
# set year, month, quarter columns
df['year'] = df['time'].apply(lambda x: x[:4])
df['month'] = df['time'].apply(lambda x:x[5:7])
df['quarter'] = df['month'].apply(lambda x: (int(x)-1)//3+1)

# %%
# set year, month, quarter columns
df['year'] = df['time'].apply(lambda x: x[:4])
df['month'] = df['time'].apply(lambda x:x[5:7])
df['quarter'] = df['month'].apply(lambda x: (int(x)-1)//3+1)

# %%
df.head()
# Out:
#                        name  meter_score  audience_score rating  \
# 0               Toy Story 3           98              89      G
# 1                 True Grit           96              85  PG-13
# 2  How to Train Your Dragon           98              91     PG
# 3         The King's Speech           95              92  PG-13
# 4                Inside Job           98              91  PG-13
#
#                                                genre  \
# 0  'Animation', 'Comedy', 'Kids & Family', 'Scien...
# 1           'Action & Adventure', 'Drama', 'Western'
# 2  'Animation', 'Kids & Family', 'Science Fiction...
# 3                                            'Drama'
# 4                  'Documentary', 'Special Interest'
#
#                                                 cast  \
# 0  'Tom Hanks', 'Tim Allen', 'Joan Cusack', 'Ned ...
# 1  'Hailee Steinfeld', 'Jeff Bridges', 'Matt Damo...
# 2  'Jay Baruchel', 'Gerard Butler', 'Craig Fergus...
# 3  'Colin Firth', 'Helena Bonham Carter', 'Geoffr...
# 4  'Matt Damon', 'William Ackman', 'Daniel Alpert...
#
#                            director        time                    studio  \
# 0                     'Lee Unkrich'  2010-06-18    'Walt Disney Pictures'
# 1         'Joel Coen', 'Ethan Coen'  2010-12-22      'Paramount Pictures'
# 2  'Dean DeBlois', ' Chris Sanders'  2010-03-26        'Paramount', 'DWA'
# 3                      'Tom Hooper'  2010-11-26   'The Weinstein Company'
# 4          'Charles Ferguson (III)'  2010-10-08  'Sony Pictures Classics'
#
#    runtime   box_office                                     movie_synopsis  \
# 0      103  414984497.0  "Toy Story 3" welcomes Woody, Buzz and the who...
# 1      110  171031347.0  Fourteen-year-old Mattie Ross (Hailee Steinfel...
# 2       98  216900000.0  The son of a Viking chief must capture a drago...
# 3      118  138300000.0  After the death of his father King George V (M...
# 4      108    4311834.0  From Academy Award (R) nominated filmmaker, Ch...
#
#    actor_score  director_score  year month  quarter
# 0          233             138  2010    06        2
# 1          273               0  2010    12        4
# 2          191               0  2010    03        1
# 3          281             403  2010    11        4
# 4           95               0  2010    10        4

# %% [markdown]
# ## Basic Analysis

# %% [markdown]
# ### Great films & Box office over year

# %%
plt.style.use('seaborn')

plt.figure(figsize=(14,10))
plt.subplot(2,1,1)
df.groupby(df['year']).size().plot(kind='bar')
plt.xlabel('year')
plt.ylabel('films')
plt.title('Great films over year')
plt.show()

plt.figure(figsize=(14,10))
plt.subplot(2,1,2)
plt.plot(df[['year','box_office']].groupby('year').sum())
plt.xlabel('year')
plt.ylabel('Box office $')
plt.title('Box office over year')
plt.show()

# %% [markdown]
# ### genre trend of great movies

# %% [markdown]
# #### genre data processing

# %%
def get_columns(df_column):
    l = []
    for ele in df_column:
        if ele!='na' and ele!='nan':
            l.extend(ele.split(', '))

    return set([x[1:-1] for x in l])

genre_list = get_columns(df['genre'])
for ele in genre_list:
    df['genre_'+str(ele)]=np.where(df["genre"].str.contains(ele),1,0)

df['genre_Total'] = df['genre'].apply(lambda x: len(x.split(', ')))

# %% [markdown]
# #### genre wordcloud

# %%
string = ' '.join(genre_list)
words=nltk.tokenize.word_tokenize(string)
origin_mask = imageio.imread("films.jpg")
wordcloud = WordCloud(stopwords=STOPWORDS,background_color='white',mask=origin_mask, contour_width=3, 
               contour_color='steelblue').generate(' '.join(words))
plt.figure(figsize=(14,7))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# #### Genre and box office distribution

# %%
genre_list = [str('genre_'+x) for x in genre_list]

# %%
genre_count = {}
box_office = {}

for genre in genre_list:
    genre_count[genre[6:]] = len(df[df[genre]==1])
    box_office[genre[6:]] = sum(df[df[genre]==1]['box_office'])

plt.figure(figsize=(14,7))
plt.subplot(1,2,1)
plt.bar(genre_count.keys(),genre_count.values())
plt.xlabel('Genre')
plt.ylabel('Count')
plt.title('Genre distribution')
plt.xticks(rotation=90,fontsize=12)

plt.subplot(1,2,2)
plt.bar(box_office.keys(),box_office.values(),color='G')
plt.xlabel('Genre')
plt.ylabel('Box Office $')
plt.title('Box office distribution')
plt.xticks(rotation=90,fontsize=12)

plt.show()

# %% [markdown]
# #### genre trend over year

# %%
from matplotlib.ticker import FuncFormatter
COL_NUM = 4
ROW_NUM = 5
fig,axes = plt.subplots(ROW_NUM, COL_NUM, figsize=(15,15))

for i, ele in enumerate(genre_list):
    ax = axes[int(i/COL_NUM), i%COL_NUM]
    ele_trend_ratio = df[df[ele]==1].groupby(df['year']).size() / len(df[df[ele]==1])
    ele_trend_ratio.plot(kind='barh',ax=ax)
    ax.set_title(ele[6:])

plt.tight_layout()

# %% [markdown]
# #### genre trend over quarter

# %%
from matplotlib.ticker import FuncFormatter
COL_NUM = 4
ROW_NUM = 5
fig,axes = plt.subplots(ROW_NUM, COL_NUM, figsize=(15,15))

for i, ele in enumerate(genre_list):
    ax = axes[int(i/COL_NUM), i%COL_NUM]
    ele_trend_ratio = df[df[ele]==1].groupby(df['quarter']).size() / len(df[df[ele]==1])
    ele_trend_ratio.plot(kind='barh',ax=ax)
    ax.set_title(ele[6:])

plt.tight_layout()

# %% [markdown]
# ### Rating distribution

# %%
plt.figure(figsize=(10,5))
df.groupby(['rating']).size().plot(kind='bar')
plt.xlabel('Film rating')
plt.ylabel('Count')
plt.title('Rating distribution')
plt.show()

# %% [markdown]
# ### Director explorations

# %% [markdown]
# #### Director data processing

# %%
dic = {}
for directors in df['director']:
    director_list = directors.split(', ')
    for director in director_list:
        dic[director] = dic.get(director,0)+1
dic = sorted(dic.items(),key=lambda x:x[1],reverse=True)

top_director = [x for x in dic if x[1]>=7]
print('Top Directors: ',top_director, '\n')
director_name = top_director[0][0][1:-1]
print('Number One Director: ',director_name)
# Out:
# Top Directors:  [("'Joel Coen'", 10), ("'Steven Soderbergh'", 8), ("'Christopher Nolan'", 7), ("'Jon Favreau'", 7), ("'Werner Herzog'", 7), ("'Steven Spielberg'", 7)]
#
# Number One Director:  Joel Coen

# %% [markdown]
# #### Brief look at top directors' preference on genre

# %%
plt.figure(figsize=(14,7))
for director in top_director:
    sub_df = df[[director[0] in directors for directors in [ele.split(', ') for ele in df['director']]]]
    record = {}
    for genre in genre_list:
        count = sum(sub_df[genre_list][genre])
        if count>0:
            record[genre[6:]]=count
    plt.bar(record.keys(),record.values(),label=director[0][1:-1])

plt.legend(loc='upper right')
plt.xlabel('Genre')
plt.ylabel('Total Films')
plt.xticks(rotation=90,fontsize=12)
plt.show()

# %% [markdown]
# #### Look closer into director 'Joel Choen'

# %%
df_JC = df[["'Joel Coen'" in directors for directors in [ele.split(', ') for ele in df['director']]]]

record = {}
box_office = {}
for genre in genre_list:
    count = sum(df_JC[genre_list][genre])
    if count>0:
        record[genre[6:]] = count
        box_office[genre[6:]] = sum(df_JC[df_JC[genre]==1]['box_office'])

plt.figure(figsize=(14,7))
plt.subplot(1,2,1)
plt.bar(record.keys(),record.values())
plt.xlabel('Genre')
plt.ylabel('Films Counts')
plt.title('Director: Joel Choen')
plt.xticks(rotation=90,fontsize=12)

plt.subplot(1,2,2)
plt.bar(box_office.keys(),box_office.values(),color='G')
plt.xlabel('Genre')
plt.ylabel('Box Office')
plt.title('Director: Joel Choen')
plt.xticks(rotation=90,fontsize=12)

plt.show()

# %% [markdown]
# # Text Mining

# %% [markdown]
# ### read in data

# %%
data = pd.read_csv("all_reviews.csv",header=0)

# %% [markdown]
# ## Preparation for text mining

# %% [markdown]
# ### 1. Hu and Liu's sentiment analysis lexicon
# http://ptrckprry.com/course/ssd/data/positive-words.txt
#
# http://ptrckprry.com/course/ssd/data/negative-words.txt

# %%
def get_pos_neg_words():
    def get_words(url):
        import requests
        words = requests.get(url).content.decode('latin-1')
        word_list = words.split('\n')
        index = 0
        while index < len(word_list):
            word = word_list[index]
            if ';' in word or not word:
                word_list.pop(index)
            else:
                index+=1
        return word_list

    #Get lists of positive and negative words
    p_url = 'http://ptrckprry.com/course/ssd/data/positive-words.txt'
    n_url = 'http://ptrckprry.com/course/ssd/data/negative-words.txt'
    positive_words = get_words(p_url)
    negative_words = get_words(n_url)
    return positive_words,negative_words

positive_words,negative_words = get_pos_neg_words()

# %% [markdown]
# ### 2. NRC sentiment data
# http://sentiment.nrc.ca/lexicons-for-research/NRC-Emotion-Lexicon.zip

# %%
def get_nrc_data():
    nrc = "NRC-emotion-lexicon-wordlevel-alphabetized-v0.92.txt"
    count=0
    emotion_dict=dict()
    with open(nrc,'r') as f:
        all_lines = list()
        for line in f:
            if count < 46:
                count+=1
                continue
            line = line.strip().split('\t')
            if int(line[2]) == 1:
                if emotion_dict.get(line[0]):
                    emotion_dict[line[0]].append(line[1])
                else:
                    emotion_dict[line[0]] = [line[1]]
    return emotion_dict
emotion_dict = get_nrc_data()

# %% [markdown]
# ### 3. Vader Analysis

# %%
def vader_comparison(texts):
    list_vc=[]
    analyzer = SentimentIntensityAnalyzer()
    for i in range(len(rev)):
        sentences = sent_tokenize(rev[i])
        positive=compound=neutral=negative=0
        for sentence in sentences:
            vs = analyzer.polarity_scores(sentence)
            positive+=vs['pos']/(len(sentences))
            compound+=vs['compound']/(len(sentences))
            neutral+=vs['neu']/(len(sentences))
            negative+=vs['neg']/(len(sentences))
        list_vc.append((positive,compound,neutral,negative))
    return list_vc

# %% [markdown]
# ## Sentiment Analysis

# %% [markdown]
# ### 1. simple analysis

# %%
rev=data['Reviews']
def do_pos_neg_sentiment_analysis(text_rev,debug=False):
    positive_words,negative_words = get_pos_neg_words()
    from nltk import word_tokenize
    results = list()
    for text in text_rev:
        cpos = cneg = lpos = lneg = 0
        for word in word_tokenize(text):
            if word in positive_words:
                if debug:
                    print("Positive",word)
                cpos+=1
            if word in negative_words:
                if debug:
                    print("Negative",word)
                cneg+=1
        results.append((cpos/len(word_tokenize(text)),cneg/len(word_tokenize(text))))
    return results

do_pos_neg_sentiment_analysis(rev)[:11]
# Out:
# [(0.050936768149882905, 0.0117096018735363),
#  (0.03663613655287261, 0.044962531223980015),
#  (0.06025824964131994, 0.024390243902439025),
#  (0.04553624925104853, 0.04313960455362492),
#  (0.05665930831493746, 0.01913171449595291),
#  (0.03663423010875787, 0.027475672581568404),
#  (0.05685218432076601, 0.02573309395571514),
#  (0.05439005439005439, 0.028749028749028748),
#  (0.043429844097995544, 0.02783964365256125),
#  (0.04154302670623145, 0.028684470820969338),
#  (0.05235602094240838, 0.035153328347045626)]

# %%
pos_neg_list=do_pos_neg_sentiment_analysis(rev)
df_sub = pd.DataFrame(columns=['positive','negative'])
for i in range(len(pos_neg_list)):
    df_sub.loc[i,'positive']=pos_neg_list[i][0]
    df_sub.loc[i,'negative']=pos_neg_list[i][1]
df_sub
# Out:
#       positive   negative
# 0    0.0509368  0.0117096
# 1    0.0366361  0.0449625
# 2    0.0602582  0.0243902
# 3    0.0455362  0.0431396
# 4    0.0566593  0.0191317
# 5    0.0366342  0.0274757
# 6    0.0568522  0.0257331
# 7    0.0543901   0.028749
# 8    0.0434298  0.0278396
# 9     0.041543  0.0286845
# 10    0.052356  0.0351533
# 11   0.0506964  0.0245125
# 12    0.046789  0.0541284
# 13   0.0546763  0.0446043
# 14   0.0659824  0.0190616
# 15   0.0545645  0.0262329
# 16   0.0500874  0.0215492
# 17   0.0570944  0.0203505
# 18       0.054      0.017
# 19   0.0624071  0.0178306
# 20   0.0303907  0.0477569
# 21   0.0419453   0.024924
# 22   0.0438024  0.0251631
# 23   0.0368272  0.0283286
# 24   0.0424528  0.0455975
# 25   0.0475687  0.0528541
# 26   0.0409556  0.0307167
# 27   0.0484234  0.0371622
# 28   0.0497057  0.0333551
# 29   0.0582011  0.0249433
# ..         ...        ...
# 470   0.030303    0.04329
# 471  0.0725191  0.0152672
# 472  0.0454879  0.0264123
# 473  0.0375648  0.0621762
# 474  0.0368969  0.0435194
# 475  0.0424028  0.0335689
# 476  0.0397351  0.0529801
# 477  0.0543319  0.0220264
# 478  0.0407801  0.0390071
# 479  0.0339168  0.0306346
# 480  0.0492701  0.0547445
# 481  0.0618337  0.0298507
# 482  0.0372024  0.0431548
# 483  0.0589812  0.0428954
# 484  0.0492866  0.0220493
# 485  0.0507365  0.0360065
# 486   0.046832  0.0165289
# 487  0.0760456   0.026616
# 488  0.0377358  0.0496524
# 489  0.0417582  0.0241758
# 490   0.054295  0.0137763
# 491  0.0396511  0.0301348
# 492  0.0299667  0.0432852
# 493  0.0416305  0.0433651
# 494  0.0500501   0.033033
# 495       0.05       0.05
# 496  0.0385233  0.0272873
# 497  0.0465116  0.0276163
# 498   0.051462   0.025731
# 499  0.0364583   0.034375
#
# [500 rows x 2 columns]

# %%
df_pos_neg=pd.concat([data, df_sub], axis=1)
df_pos_neg
# Out:
#                               Movie_Name  Year  \
# 0                                Boyhood  2014
# 1                           The Babadook  2014
# 2                         The LEGO Movie  2014
# 3                           Nightcrawler  2014
# 4                            Life Itself  2014
# 5                               Whiplash  2014
# 6                                Birdman  2014
# 7                             Mr. Turner  2014
# 8                    Two Days, One Night  2014
# 9                                 Gloria  2014
# 10                           Snowpiercer  2014
# 11               Guardians of the Galaxy  2014
# 12                             Leviathan  2014
# 13                            Starred Up  2014
# 14       The Tale of the Princess Kaguya  2014
# 15              The Grand Budapest Hotel  2014
# 16            X-Men: Days of Future Past  2014
# 17     Live Die Repeat: Edge of Tomorrow  2014
# 18                     Jodorowsky's Dune  2014
# 19                       Song Of The Sea  2014
# 20                   The Missing Picture  2014
# 21        Dawn Of The Planet Of The Apes  2014
# 22                                   Ida  2014
# 23                           Citizenfour  2014
# 24                      The Overnighters  2014
# 25                             Blue Ruin  2014
# 26                               Ilo Ilo  2014
# 27                      We Are the Best!  2014
# 28                    The Imitation Game  2014
# 29                       Love Is Strange  2014
# ..                                   ...   ...
# 470                       Border (Gräns)  2018
# 471    To All the Boys I've Loved Before  2018
# 472                                Tully  2018
# 473                    Burning (Beoning)  2018
# 474                         Lean on Pete  2018
# 475                           Bisbee '17  2018
# 476                              Western  2018
# 477                     Hearts Beat Loud  2018
# 478                        Journey's End  2018
# 479                     American Animals  2018
# 480                              Revenge  2018
# 481  Robin Williams: Come Inside My Mind  2018
# 482                           Nico, 1988  2018
# 483           If Beale Street Could Talk  2018
# 484                    Support the Girls  2018
# 485        Teen Titans Go! To the Movies  2018
# 486       The Guardians (Les Gardiennes)  2018
# 487                                  CAM  2018
# 488                       A Simple Favor  2018
# 489                            24 Frames  2018
# 490                         Molly's Game  2018
# 491            Ralph Breaks the Internet  2018
# 492                              Whitney  2018
# 493                            Halloween  2018
# 494                           Game Night  2018
# 495                 A Prayer Before Dawn  2018
# 496                       We the Animals  2018
# 497                              Upgrade  2018
# 498                              Colette  2018
# 499     The Miseducation of Cameron Post  2018
#
#                                                Reviews   positive   negative
# 0    [" Like Michael Apted in his Seven Up! documen...  0.0509368  0.0117096
# 1    [' A deftly inventive and psychologically char...  0.0366361  0.0449625
# 2    [' The movie is a wonderful surprise, cleverly...  0.0602582  0.0243902
# 3    [' Like an alternate version of Network in whi...  0.0455362  0.0431396
# 4    [" With Ebert's blessing and encouragement, Li...  0.0566593  0.0191317
# 5    [' Revealing both the dangers and payoffs of a...  0.0366342  0.0274757
# 6    [' Birdman, more than most, seems a film that ...  0.0568522  0.0257331
# 7    [" Mike Leigh's biopic is so richly detailed t...  0.0543901   0.028749
# 8    [" Consider Marion Cotillard's Oscar-nominated...  0.0434298  0.0278396
# 9    [" We don't make movies in America like Gloria...   0.041543  0.0286845
# 10   [" That rare experience you don't get to have ...   0.052356  0.0351533
# 11   [' If Guardians of the Galaxy is an origin sto...  0.0506964  0.0245125
# 12   [' A palpable and melancholy aura of resignati...   0.046789  0.0541284
# 13   [' Mackenzie is seeking to understand how all ...  0.0546763  0.0446043
# 14   [' Plays out as a wistful, slow-burning romanc...  0.0659824  0.0190616
# 15   [' "The Grand Budapest Hotel" is not his grand...  0.0545645  0.0262329
# 16   [' It is especially impressive that Days of Fu...  0.0500874  0.0215492
# 17   [' Edge of Tomorrow is the perfect mix of blus...  0.0570944  0.0203505
# 18   [' Pavich shows us many images from the storyb...      0.054      0.017
# 19   [' "Song of the Sea" creates a magical world, ...  0.0624071  0.0178306
# 20   [' Panh fulfills his debts to the dead not jus...  0.0303907  0.0477569
# 21   [" Dawn is not interested in staging conflict ...  0.0419453   0.024924
# 22   [" Now that Paweł Pawlikowski's haunting Polis...  0.0438024  0.0251631
# 23   [" Poitras' movie works even better as a horro...  0.0368272  0.0283286
# 24   [' It develops into a study of obsession, hypo...  0.0424528  0.0455975
# 25   [" The world doesn't need another empty genre ...  0.0475687  0.0528541
# 26   [' Chen builds his case not with sentimentalit...  0.0409556  0.0307167
# 27   [' A pallid and terminally cutesy movie that s...  0.0484234  0.0371622
# 28   [' A moving tribute to an extraordinary man.',...  0.0497057  0.0333551
# 29   [" 'Love is Strange' takes something so right ...  0.0582011  0.0249433
# ..                                                 ...        ...        ...
# 470  [" Don't read another word about it: just go."...   0.030303    0.04329
# 471  [" Centineo performs a type of compassionate m...  0.0725191  0.0152672
# 472  [' As a portrayal of postpartum depression, Tu...  0.0454879  0.0264123
# 473  [' A languorous, catlike psychological puzzle ...  0.0375648  0.0621762
# 474  [" In Charley's America, love is the rarest th...  0.0368969  0.0435194
# 475  [' A fascinating exercise in nonfiction filmma...  0.0424028  0.0335689
# 476  [' Like its title, "Western" is both startling...  0.0397351  0.0529801
# 477  [' A keenly observed story of a Brooklyn fathe...  0.0543319  0.0220264
# 478  [' Its cerebral message boils down to a "war i...  0.0407801  0.0390071
# 479  [' "American Animals" is one of the year\'s sm...  0.0339168  0.0306346
# 480  [' What happens next is expected-a roaring ram...  0.0492701  0.0547445
# 481  [' Tinged with nostalgia and emotion, Robin Wi...  0.0618337  0.0298507
# 482  [' "I\'m selective about my audience," says th...  0.0372024  0.0431548
# 483  [" Something else guides Jenkins, generally an...  0.0589812  0.0428954
# 484  [" Support the Girls somehow manages to do it ...  0.0492866  0.0220493
# 485  [" Most of the gags in this pandering spoof ar...  0.0507365  0.0360065
# 486  [' Like the cinematic equivalent of slow food,...   0.046832  0.0165289
# 487  [' "Cam" plays with both psychological-horror ...  0.0760456   0.026616
# 488  [" It keeps you on the edge of your seat and, ...  0.0377358  0.0496524
# 489  [' "24 Frames" is slow cinema at its slowest, ...  0.0417582  0.0241758
# 490  [' While the script crackles and excites, the ...   0.054295  0.0137763
# 491  [" It's pretty incredible to see how the filmm...  0.0396511  0.0301348
# 492  [' The film is a sad calamity of conflicting n...  0.0299667  0.0432852
# 493  [' A brutal rumination on intergenerational pa...  0.0416305  0.0433651
# 494  [' The movie is a hollow throwback to classic ...  0.0500501   0.033033
# 495  [' Once the audience adjusts to its rhythms, i...       0.05       0.05
# 496  [' This movie is so gorgeous, it even makes dr...  0.0385233  0.0272873
# 497  [' Upgrade is a brutish, efficient and well-ex...  0.0465116  0.0276163
# 498  [" There's more going on in Colette than tame ...   0.051462   0.025731
# 499  [' [Post] is anchored by a strong performance ...  0.0364583   0.034375
#
# [500 rows x 5 columns]

# %% [markdown]
# ### 2.NRC Analysis

# %%
def emotion_analyzer(text,emotion_dict=emotion_dict):
    emotions = {x for y in emotion_dict.values() for x in y}
    emotion_count = dict()
    for emotion in emotions:
        emotion_count[emotion] = 0
    total_words = len(text.split())
    for word in text.split():
        if emotion_dict.get(word):
            for emotion in emotion_dict.get(word):
                emotion_count[emotion] += 1/len(text.split())
    return emotion_count

# %%
def comparative_emotion_analyzer(text_rev):
    df_comp = pd.DataFrame(columns=['Fear','Trust','sub-Negative',
                           'sub-Positive','Joy','Disgust','Anticipation',
                           'Sadness','Surprise','Anger'],)   
    dict_list=[]
    for text in text_rev:
        result=emotion_analyzer(text)
        dict_list.append(result)
        for i in range(len(dict_list)):
            df_comp.loc[i, 'Fear'] = dict_list[i]['fear']
            df_comp.loc[i, 'Trust'] = dict_list[i]['trust']
            df_comp.loc[i, 'sub-Negative'] = dict_list[i]['negative']
            df_comp.loc[i, 'sub-Positive'] = dict_list[i]['positive']
            df_comp.loc[i, 'Joy'] = dict_list[i]['joy']
            df_comp.loc[i, 'Disgust'] = dict_list[i]['disgust']
            df_comp.loc[i, 'Anticipation'] = dict_list[i]['anticipation']
            df_comp.loc[i, 'Sadness'] = dict_list[i]['sadness']
            df_comp.loc[i, 'Surprise'] = dict_list[i]['surprise']
            df_comp.loc[i, 'Anger'] = dict_list[i]['anger']
    return df_comp
df_comparative=comparative_emotion_analyzer(rev)

# %%
df_comprehensive=pd.concat([df_pos_neg, df_comparative], axis=1)
df_comprehensive
# Out:
#                               Movie_Name  Year  \
# 0                                Boyhood  2014
# 1                           The Babadook  2014
# 2                         The LEGO Movie  2014
# 3                           Nightcrawler  2014
# 4                            Life Itself  2014
# 5                               Whiplash  2014
# 6                                Birdman  2014
# 7                             Mr. Turner  2014
# 8                    Two Days, One Night  2014
# 9                                 Gloria  2014
# 10                           Snowpiercer  2014
# 11               Guardians of the Galaxy  2014
# 12                             Leviathan  2014
# 13                            Starred Up  2014
# 14       The Tale of the Princess Kaguya  2014
# 15              The Grand Budapest Hotel  2014
# 16            X-Men: Days of Future Past  2014
# 17     Live Die Repeat: Edge of Tomorrow  2014
# 18                     Jodorowsky's Dune  2014
# 19                       Song Of The Sea  2014
# 20                   The Missing Picture  2014
# 21        Dawn Of The Planet Of The Apes  2014
# 22                                   Ida  2014
# 23                           Citizenfour  2014
# 24                      The Overnighters  2014
# 25                             Blue Ruin  2014
# 26                               Ilo Ilo  2014
# 27                      We Are the Best!  2014
# 28                    The Imitation Game  2014
# 29                       Love Is Strange  2014
# ..                                   ...   ...
# 470                       Border (Gräns)  2018
# 471    To All the Boys I've Loved Before  2018
# 472                                Tully  2018
# 473                    Burning (Beoning)  2018
# 474                         Lean on Pete  2018
# 475                           Bisbee '17  2018
# 476                              Western  2018
# 477                     Hearts Beat Loud  2018
# 478                        Journey's End  2018
# 479                     American Animals  2018
# 480                              Revenge  2018
# 481  Robin Williams: Come Inside My Mind  2018
# 482                           Nico, 1988  2018
# 483           If Beale Street Could Talk  2018
# 484                    Support the Girls  2018
# 485        Teen Titans Go! To the Movies  2018
# 486       The Guardians (Les Gardiennes)  2018
# 487                                  CAM  2018
# 488                       A Simple Favor  2018
# 489                            24 Frames  2018
# 490                         Molly's Game  2018
# 491            Ralph Breaks the Internet  2018
# 492                              Whitney  2018
# 493                            Halloween  2018
# 494                           Game Night  2018
# 495                 A Prayer Before Dawn  2018
# 496                       We the Animals  2018
# 497                              Upgrade  2018
# 498                              Colette  2018
# 499     The Miseducation of Cameron Post  2018
#
#                                                Reviews   positive   negative  \
# 0    [" Like Michael Apted in his Seven Up! documen...  0.0509368  0.0117096
# 1    [' A deftly inventive and psychologically char...  0.0366361  0.0449625
# 2    [' The movie is a wonderful surprise, cleverly...  0.0602582  0.0243902
# 3    [' Like an alternate version of Network in whi...  0.0455362  0.0431396
# 4    [" With Ebert's blessing and encouragement, Li...  0.0566593  0.0191317
# 5    [' Revealing both the dangers and payoffs of a...  0.0366342  0.0274757
# 6    [' Birdman, more than most, seems a film that ...  0.0568522  0.0257331
# 7    [" Mike Leigh's biopic is so richly detailed t...  0.0543901   0.028749
# 8    [" Consider Marion Cotillard's Oscar-nominated...  0.0434298  0.0278396
# 9    [" We don't make movies in America like Gloria...   0.041543  0.0286845
# 10   [" That rare experience you don't get to have ...   0.052356  0.0351533
# 11   [' If Guardians of the Galaxy is an origin sto...  0.0506964  0.0245125
# 12   [' A palpable and melancholy aura of resignati...   0.046789  0.0541284
# 13   [' Mackenzie is seeking to understand how all ...  0.0546763  0.0446043
# 14   [' Plays out as a wistful, slow-burning romanc...  0.0659824  0.0190616
# 15   [' "The Grand Budapest Hotel" is not his grand...  0.0545645  0.0262329
# 16   [' It is especially impressive that Days of Fu...  0.0500874  0.0215492
# 17   [' Edge of Tomorrow is the perfect mix of blus...  0.0570944  0.0203505
# 18   [' Pavich shows us many images from the storyb...      0.054      0.017
# 19   [' "Song of the Sea" creates a magical world, ...  0.0624071  0.0178306
# 20   [' Panh fulfills his debts to the dead not jus...  0.0303907  0.0477569
# 21   [" Dawn is not interested in staging conflict ...  0.0419453   0.024924
# 22   [" Now that Paweł Pawlikowski's haunting Polis...  0.0438024  0.0251631
# 23   [" Poitras' movie works even better as a horro...  0.0368272  0.0283286
# 24   [' It develops into a study of obsession, hypo...  0.0424528  0.0455975
# 25   [" The world doesn't need another empty genre ...  0.0475687  0.0528541
# 26   [' Chen builds his case not with sentimentalit...  0.0409556  0.0307167
# 27   [' A pallid and terminally cutesy movie that s...  0.0484234  0.0371622
# 28   [' A moving tribute to an extraordinary man.',...  0.0497057  0.0333551
# 29   [" 'Love is Strange' takes something so right ...  0.0582011  0.0249433
# ..                                                 ...        ...        ...
# 470  [" Don't read another word about it: just go."...   0.030303    0.04329
# 471  [" Centineo performs a type of compassionate m...  0.0725191  0.0152672
# 472  [' As a portrayal of postpartum depression, Tu...  0.0454879  0.0264123
# 473  [' A languorous, catlike psychological puzzle ...  0.0375648  0.0621762
# 474  [" In Charley's America, love is the rarest th...  0.0368969  0.0435194
# 475  [' A fascinating exercise in nonfiction filmma...  0.0424028  0.0335689
# 476  [' Like its title, "Western" is both startling...  0.0397351  0.0529801
# 477  [' A keenly observed story of a Brooklyn fathe...  0.0543319  0.0220264
# 478  [' Its cerebral message boils down to a "war i...  0.0407801  0.0390071
# 479  [' "American Animals" is one of the year\'s sm...  0.0339168  0.0306346
# 480  [' What happens next is expected-a roaring ram...  0.0492701  0.0547445
# 481  [' Tinged with nostalgia and emotion, Robin Wi...  0.0618337  0.0298507
# 482  [' "I\'m selective about my audience," says th...  0.0372024  0.0431548
# 483  [" Something else guides Jenkins, generally an...  0.0589812  0.0428954
# 484  [" Support the Girls somehow manages to do it ...  0.0492866  0.0220493
# 485  [" Most of the gags in this pandering spoof ar...  0.0507365  0.0360065
# 486  [' Like the cinematic equivalent of slow food,...   0.046832  0.0165289
# 487  [' "Cam" plays with both psychological-horror ...  0.0760456   0.026616
# 488  [" It keeps you on the edge of your seat and, ...  0.0377358  0.0496524
# 489  [' "24 Frames" is slow cinema at its slowest, ...  0.0417582  0.0241758
# 490  [' While the script crackles and excites, the ...   0.054295  0.0137763
# 491  [" It's pretty incredible to see how the filmm...  0.0396511  0.0301348
# 492  [' The film is a sad calamity of conflicting n...  0.0299667  0.0432852
# 493  [' A brutal rumination on intergenerational pa...  0.0416305  0.0433651
# 494  [' The movie is a hollow throwback to classic ...  0.0500501   0.033033
# 495  [' Once the audience adjusts to its rhythms, i...       0.05       0.05
# 496  [' This movie is so gorgeous, it even makes dr...  0.0385233  0.0272873
# 497  [' Upgrade is a brutish, efficient and well-ex...  0.0465116  0.0276163
# 498  [" There's more going on in Colette than tame ...   0.051462   0.025731
# 499  [' [Post] is anchored by a strong performance ...  0.0364583   0.034375
#
#            Fear       Trust sub-Negative sub-Positive         Joy  \
# 0    0.00502874   0.0186782   0.00933908    0.0438218   0.0186782
# 1     0.0343782    0.016178    0.0525784    0.0374115    0.016178
# 2    0.00616197    0.022007    0.0167254    0.0501761   0.0246479
# 3     0.0146199   0.0197368    0.0255848    0.0438596   0.0153509
# 4     0.0145587   0.0291174     0.021838    0.0618744   0.0254777
# 5     0.0134371   0.0219236    0.0240453    0.0417256   0.0212164
# 6     0.0141791   0.0253731    0.0223881    0.0470149   0.0238806
# 7    0.00771456   0.0221794    0.0260366    0.0501446   0.0231437
# 8     0.0111421   0.0264624    0.0181058    0.0431755   0.0125348
# 9    0.00752823   0.0175659    0.0188206    0.0401506   0.0150565
# 10    0.0121043   0.0130354    0.0223464    0.0502793   0.0148976
# 11   0.00813559   0.0176271    0.0183051    0.0420339   0.0230508
# 12    0.0235426   0.0168161    0.0515695     0.043722   0.0156951
# 13    0.0369069   0.0193322    0.0421793    0.0421793   0.0123023
# 14    0.0125899   0.0431655    0.0161871    0.0863309    0.044964
# 15   0.00912052   0.0169381    0.0169381    0.0501629   0.0208469
# 16   0.00863931   0.0187185    0.0201584    0.0417567   0.0165587
# 17    0.0118138   0.0215427    0.0159833    0.0507297   0.0222377
# 18     0.010101    0.020202    0.0239899    0.0681818   0.0239899
# 19    0.0127505   0.0291439    0.0200364    0.0601093   0.0346084
# 20     0.026643   0.0230906    0.0390764    0.0337478   0.0106572
# 21   0.00811808   0.0214022    0.0162362    0.0472325   0.0199262
# 22    0.0141509   0.0224057    0.0200472    0.0424528   0.0200472
# 23    0.0127907    0.022093    0.0209302    0.0395349  0.00813953
# 24     0.017341   0.0134875    0.0250482    0.0327553  0.00770713
# 25    0.0363165   0.0181582    0.0376135    0.0453956   0.0142672
# 26     0.017316    0.021645     0.021645     0.038961  0.00865801
# 27     0.015493   0.0295775    0.0309859     0.056338   0.0338028
# 28    0.0137429   0.0250606    0.0274859    0.0517381   0.0250606
# 29   0.00932836   0.0242537    0.0195896    0.0531716   0.0205224
# ..          ...         ...          ...          ...         ...
# 470   0.0213904    0.026738    0.0213904     0.040107   0.0160428
# 471  0.00956938   0.0143541    0.0191388    0.0526316   0.0191388
# 472  0.00629496   0.0242806    0.0152878    0.0386691   0.0215827
# 473   0.0159744   0.0127796    0.0255591     0.043131   0.0159744
# 474  0.00807382   0.0184544    0.0288351    0.0553633   0.0184544
# 475   0.0218818   0.0196937    0.0262582    0.0547046   0.0131291
# 476  0.00833333  0.00833333   0.00833333    0.0583333  0.00833333
# 477  0.00740741   0.0277778    0.0111111    0.0462963   0.0240741
# 478   0.0286344   0.0154185     0.030837    0.0440529   0.0154185
# 479   0.0135501   0.0257453    0.0257453    0.0542005   0.0176152
# 480   0.0525114   0.0159817    0.0593607    0.0502283   0.0228311
# 481   0.0158311   0.0290237    0.0184697    0.0474934   0.0131926
# 482   0.0204842   0.0167598     0.027933    0.0391061   0.0223464
# 483    0.022508   0.0353698    0.0321543    0.0771704   0.0610932
# 484  0.00475436   0.0253566   0.00792393    0.0507132   0.0158479
# 485  0.00196464   0.0176817    0.0176817    0.0412574    0.021611
# 486    0.023569    0.020202     0.020202     0.047138    0.023569
# 487  0.00473934   0.0236967    0.0189573    0.0616114    0.028436
# 488   0.0143541  0.00956938    0.0358852    0.0334928   0.0167464
# 489  0.00810811   0.0108108   0.00540541    0.0378378   0.0243243
# 490  0.00833333       0.025    0.0135417    0.0447917   0.0229167
# 491  0.00790514   0.0217391    0.0148221     0.034585   0.0197628
# 492  0.00826446    0.023416    0.0275482    0.0399449   0.0151515
# 493   0.0240175   0.0152838    0.0316594    0.0305677  0.00982533
# 494   0.0122249   0.0256724    0.0268949    0.0513447   0.0232274
# 495      0.0375   0.0416667    0.0458333        0.075        0.05
# 496  0.00994036   0.0139165    0.0218688    0.0357853   0.0198807
# 497   0.0148976   0.0260708    0.0242086    0.0558659   0.0223464
# 498  0.00434153   0.0217077    0.0101302    0.0520984   0.0202605
# 499   0.0139241   0.0240506    0.0278481    0.0518987   0.0151899
#
#          Disgust Anticipation     Sadness    Surprise       Anger
# 0    0.000718391    0.0150862  0.00359195  0.00502874  0.00215517
# 1      0.0222447     0.016178   0.0343782   0.0202224   0.0252781
# 2     0.00352113    0.0176056  0.00352113   0.0158451  0.00792254
# 3     0.00804094    0.0175439   0.0124269  0.00804094   0.0116959
# 4     0.00545951    0.0245678  0.00909918   0.0100091  0.00727934
# 5     0.00919378    0.0183876   0.0106082   0.0148515   0.0141443
# 6     0.00820896    0.0231343  0.00671642   0.0126866  0.00970149
# 7      0.0125362    0.0183221   0.0106075   0.0115718  0.00867888
# 8     0.00417827    0.0181058   0.0097493  0.00557103  0.00557103
# 9     0.00501882    0.0138018   0.0125471  0.00878294  0.00752823
# 10    0.00837989    0.0158287   0.0139665  0.00837989   0.0102421
# 11     0.0040678     0.019661  0.00677966   0.0142373  0.00813559
# 12     0.0179372    0.0190583   0.0246637   0.0134529   0.0235426
# 13     0.0140598    0.0175747   0.0193322   0.0105448   0.0316344
# 14    0.00719424    0.0197842   0.0143885   0.0143885   0.0107914
# 15    0.00456026    0.0110749  0.00716612  0.00977199  0.00716612
# 16    0.00647948    0.0151188  0.00719942   0.0136789  0.00863931
# 17    0.00416956    0.0215427   0.0104239   0.0111188   0.0076442
# 18    0.00252525    0.0340909   0.0113636   0.0138889  0.00126263
# 19    0.00728597    0.0236794    0.010929   0.0163934   0.0127505
# 20     0.0142096    0.0230906   0.0159858   0.0106572   0.0159858
# 21    0.00442804    0.0243542  0.00738007   0.0103321  0.00885609
# 22    0.00471698    0.0165094   0.0165094   0.0106132  0.00943396
# 23    0.00697674   0.00930233  0.00813953   0.0116279   0.0116279
# 24    0.00578035    0.0192678  0.00963391   0.0115607  0.00578035
# 25    0.00648508    0.0337224   0.0155642   0.0298314   0.0337224
# 26      0.004329   0.00865801    0.017316    0.004329    0.004329
# 27     0.0084507    0.0211268   0.0140845   0.0169014    0.015493
# 28    0.00565885    0.0194018   0.0153597   0.0137429  0.00970089
# 29    0.00466418    0.0186567   0.0158582    0.011194  0.00932836
# ..           ...          ...         ...         ...         ...
# 470   0.00802139    0.0213904  0.00802139    0.013369   0.0106952
# 471   0.00478469   0.00956938  0.00956938   0.0143541  0.00956938
# 472   0.00719424    0.0107914   0.0116906  0.00809353  0.00629496
# 473    0.0111821    0.0239617   0.0127796   0.0159744   0.0111821
# 474    0.0138408    0.0149942    0.017301   0.0103806  0.00461361
# 475    0.0109409    0.0196937   0.0131291   0.0109409   0.0175055
# 476            0        0.025           0       0.025  0.00833333
# 477   0.00185185    0.0111111   0.0111111  0.00555556  0.00555556
# 478    0.0110132    0.0132159   0.0220264  0.00440529   0.0110132
# 479    0.0108401    0.0257453   0.0121951   0.0108401   0.0149051
# 480    0.0273973    0.0251142   0.0273973   0.0273973   0.0365297
# 481    0.0105541    0.0105541   0.0131926   0.0105541  0.00791557
# 482   0.00931099    0.0111732    0.018622  0.00558659   0.0167598
# 483    0.0160772    0.0257235   0.0257235   0.0192926   0.0257235
# 484   0.00158479    0.0126783   0.0110935   0.0126783  0.00475436
# 485            0    0.0157171  0.00392927   0.0157171  0.00589391
# 486     0.016835     0.023569    0.020202    0.010101  0.00673401
# 487            0    0.0236967  0.00473934  0.00947867  0.00473934
# 488   0.00956938    0.0203349  0.00956938   0.0155502   0.0143541
# 489            0    0.0243243  0.00540541  0.00540541   0.0027027
# 490   0.00520833        0.025    0.009375    0.015625     0.00625
# 491  0.000988142    0.0177866  0.00592885  0.00790514  0.00395257
# 492   0.00550964    0.0151515   0.0123967   0.0123967   0.0123967
# 493    0.0196507    0.0152838    0.018559   0.0163755   0.0207424
# 494   0.00488998    0.0207824   0.0134474   0.0122249  0.00733496
# 495    0.0291667    0.0416667   0.0208333       0.025   0.0333333
# 496   0.00795229    0.0198807  0.00596421  0.00795229  0.00994036
# 497    0.0130354    0.0204842   0.0111732   0.0148976   0.0130354
# 498   0.00144718    0.0144718  0.00868307   0.0130246  0.00434153
# 499   0.00379747    0.0189873   0.0177215   0.0101266  0.00379747
#
# [500 rows x 15 columns]

# %% [markdown]
# #### Calculate Net Positive and Net Negative Score

# %%
df_comprehensive["All_Pos"]=(df_comprehensive['Trust']+df_comprehensive['sub-Positive']+ 
                             df_comprehensive['Joy']+ df_comprehensive['Anticipation']+
                            df_comprehensive['Surprise'])
df_comprehensive["All_Neg"]=(df_comprehensive['Fear']+df_comprehensive['sub-Negative']+ 
                             df_comprehensive['Disgust']+ df_comprehensive['Sadness']+
                            df_comprehensive['Anger'])
df_comprehensive['Net']=df_comprehensive["All_Pos"]-df_comprehensive["All_Neg"]
df_comprehensive.sort_values(by="Net",ascending=False)[['Movie_Name','Net']]
# Out:
#                                             Movie_Name        Net
# 268             Long Way North (Tout en haut du monde)    0.18125
# 396                                     All This Panic   0.174157
# 449                                       Science Fair   0.171717
# 36                                  Ernest & Célestine   0.165303
# 129                                               Iris   0.162521
# 221                                        Sing Street   0.156965
# 412                                  Crazy Rich Asians   0.151292
# 337                        Your Name. (Kimi No Na Wa.)   0.148148
# 14                     The Tale of the Princess Kaguya   0.147482
# 319                   Faces Places (Visages, villages)   0.140411
# 184                       Peggy Guggenheim: Art Addict   0.140299
# 286            Miss Hokusai (Sarusuberi: Miss Hokusai)       0.14
# 389                                               Gook   0.139108
# 461                                      The Cakemaker   0.138122
# 294                                       City Of Gold   0.135177
# 299    Eat That Question: Frank Zappa in His Own Words   0.134251
# 350                                               Step   0.133913
# 267  April and the Extraordinary World (Avril et le...   0.133721
# 50                                    National Gallery   0.132265
# 35                                        The Lunchbox    0.13181
# 161                                        The Wonders   0.131373
# 406                                      Incredibles 2   0.131346
# 323                                        Logan Lucky   0.131323
# 210                                              Moana   0.130909
# 399              The Son of Joseph (Le fils de Joseph)   0.129771
# 274                                 Southside With You   0.128449
# 80                                         To Be Takei   0.125731
# 265                                       Gimme Danger   0.125184
# 269                                              Nuts!   0.124324
# 68                                                Chef   0.119695
# ..                                                 ...        ...
# 127                                            Sicario -0.0200573
# 133                                The Look of Silence -0.0229133
# 164                                Beasts of No Nation -0.0248175
# 145                                   Welcome To Leith -0.0248963
# 89                                           Siddharth  -0.024911
# 493                                          Halloween -0.0272926
# 137                                                '71 -0.0276442
# 241                                               13th -0.0280899
# 65   The Internet's Own Boy: The Story of Aaron Swartz -0.0286396
# 70                                        Child's Pose -0.0308442
# 12                                           Leviathan -0.0325112
# 390                        Land of Mine (Under Sandet) -0.0342052
# 119                                            Phoenix -0.0344168
# 374                                  It Comes At Night -0.0345508
# 181                                        James White -0.0355619
# 215                                          The Witch  -0.037037
# 177                                 The Hunting Ground -0.0382716
# 13                                          Starred Up -0.0421793
# 86                                       Cheap Thrills -0.0425532
# 394                                            Detroit -0.0433628
# 289                                     A War (Krigen)  -0.044335
# 393                                           Prevenge  -0.047138
# 282                Creepy (Kuripi: Itsuwari no rinjin) -0.0588235
# 398                                   Clash (Eshtebak) -0.0603015
# 123                                           Timbuktu -0.0603217
# 480                                            Revenge -0.0616438
# 1                                         The Babadook -0.0626896
# 88                                       The Kill Team -0.0656168
# 422                                         Hereditary -0.0872727
# 228                              The Wailing (Goksung)  -0.091195
#
# [500 rows x 2 columns]

# %% [markdown]
# ##### word cloud for four movies with highest positive score

# %%
# %matplotlib inline
DELETE_WORDS = []
def remove_words(text_string,DELETE_WORDS=DELETE_WORDS):
    for word in DELETE_WORDS:
        text_string = text_string.replace(word,' ')
    return text_string

MIN_LENGTH = 0
def remove_short_words(text_string,min_length = MIN_LENGTH):
    word_list = text_string.split()
    for word in word_list:
        if len(word) < min_length:
            text_string = text_string.replace(' '+word+' ',' ',1)
    return text_string


COL_NUM = 2
ROW_NUM = 2
fig, axes = plt.subplots(ROW_NUM, COL_NUM, figsize=(12,12))
dic={'0':268, '1':396, '2': 449,'3': 36}
for i in dic.keys():
    text_string = remove_words(rev[dic[i]])
    text_string = remove_short_words(rev[dic[i]])
    ax = axes[int(i)//2, int(i)%2] 
    ax.set_title(df_comprehensive['Movie_Name'][dic[i]])
    wordcloud = WordCloud(stopwords=STOPWORDS,background_color='white',width=1200,height=1000,max_words=20).generate(text_string)
    ax.imshow(wordcloud)
    ax.axis('off')
plt.show()

# %% [markdown]
# ### 3. Vader Analysis

# %%
list_vc_rev=vader_comparison(rev)
df_vc = pd.DataFrame(columns=['vader-comparison-positive','coumpound','neutral','vader-comparison-negative'])
for i in range(len(list_vc_rev)):
    df_vc.loc[i,'vader-comparison-positive']=list_vc_rev[i][0]
    df_vc.loc[i,'coumpound']=list_vc_rev[i][1]
    df_vc.loc[i,'neutral']=list_vc_rev[i][1]
    df_vc.loc[i,'vader-comparison-negative']=list_vc_rev[i][1]

# %%
df_overall=pd.concat([df_comprehensive, df_vc], axis=1)
df_overall['vader-net']=df_overall["vader-comparison-positive"]-df_overall["vader-comparison-negative"]
df_overall.sort_values(by="vader-net",ascending=False)[['Movie_Name','vader-net']]
#Calculate the vader-net score and sort them in descending values
# Out:
#                                             Movie_Name vader-net
# 88                                       The Kill Team  0.411381
# 227                                   Under The Shadow  0.340624
# 89                                           Siddharth  0.337217
# 25                                           Blue Ruin  0.333346
# 422                                         Hereditary  0.312362
# 177                                 The Hunting Ground  0.301836
# 329                                     City of Ghosts  0.288677
# 398                                   Clash (Eshtebak)    0.2761
# 20                                 The Missing Picture  0.262892
# 394                                            Detroit  0.262591
# 289                                     A War (Krigen)   0.24761
# 133                                The Look of Silence  0.235139
# 480                                            Revenge  0.232859
# 65   The Internet's Own Boy: The Story of Aaron Swartz  0.229223
# 381                                             Frantz  0.225421
# 1                                         The Babadook  0.225404
# 137                                                '71  0.214414
# 440                                Loveless (Nelyubov)  0.213279
# 164                                Beasts of No Nation  0.203887
# 206                                 Hell or High Water  0.203014
# 478                                      Journey's End  0.201646
# 215                                          The Witch  0.197257
# 123                                           Timbuktu  0.193397
# 384                                         Human Flow  0.191021
# 374                                  It Comes At Night  0.190054
# 228                              The Wailing (Goksung)    0.1823
# 192                                        Cartel Land  0.180234
# 218                                     Eye In The Sky  0.176167
# 450                                            Foxtrot  0.175666
# 364                                             Thelma  0.174664
# ..                                                 ...       ...
# 18                                   Jodorowsky's Dune -0.239321
# 409                               Call Me by Your Name -0.240688
# 39                                          The Rocket -0.242215
# 125                           Seymour: An Introduction -0.246361
# 57                                   Dear White People -0.247592
# 337                        Your Name. (Kimi No Na Wa.) -0.250445
# 300                                          Lady Bird -0.252855
# 37                                     A Summer's Tale -0.254229
# 397                                        School Life -0.254664
# 243                                     Queen of Katwe -0.256619
# 237                                           Aquarius -0.258061
# 189                        Disneynature Monkey Kingdom -0.258126
# 368    The B-Side: Elsa Dorfman's Portrait Photography -0.267025
# 449                                       Science Fair -0.268827
# 114                                         Paddington -0.268929
# 213                                  Love & Friendship  -0.26928
# 350                                               Step -0.275004
# 280                                  The Little Prince -0.278732
# 221                                        Sing Street -0.281412
# 461                                      The Cakemaker  -0.28172
# 210                                              Moana -0.283096
# 319                   Faces Places (Visages, villages) -0.293327
# 35                                        The Lunchbox -0.293359
# 129                                               Iris -0.295342
# 412                                  Crazy Rich Asians -0.303485
# 347                                               Dina -0.304706
# 486                     The Guardians (Les Gardiennes)   -0.3135
# 371                The Women's Balcony (Ismach Hatani) -0.314175
# 268             Long Way North (Tout en haut du monde) -0.319293
# 36                                  Ernest & Célestine -0.326497
#
# [500 rows x 2 columns]

# %% [markdown]
# #### word cloud for four movies with highest vader-net score¶

# %%
# %matplotlib inline
DELETE_WORDS = []
def remove_words(text_string,DELETE_WORDS=DELETE_WORDS):
    for word in DELETE_WORDS:
        text_string = text_string.replace(word,' ')
    return text_string

MIN_LENGTH = 0
def remove_short_words(text_string,min_length = MIN_LENGTH):
    word_list = text_string.split()
    for word in word_list:
        if len(word) < min_length:
            text_string = text_string.replace(' '+word+' ',' ',1)
    return text_string


COL_NUM = 2
ROW_NUM = 2
fig, axes = plt.subplots(ROW_NUM, COL_NUM, figsize=(12,12))
dic={'0':88, '1':227, '2': 89,'3': 25}
for i in dic.keys():
    text_string = remove_words(rev[dic[i]])
    text_string = remove_short_words(rev[dic[i]])
    ax = axes[int(i)//2, int(i)%2] 
    ax.set_title(df_comprehensive['Movie_Name'][dic[i]])
    wordcloud = WordCloud(stopwords=STOPWORDS,background_color='white',width=1200,height=1000,max_words=20).generate(text_string)
    ax.imshow(wordcloud)
    ax.axis('off')
plt.show()

# %% [markdown]
# It could be seen that the result of NRC-emotion lexicon wordlevel sentiment analysis is quite different from the result of vader sentiment analysis. In our optinion, the NRC-emotion model is relatively more accurate than the vader model. This is due to the fact that we only use the positive and negative scores in the vader model to caluculate the net and ignore the neutral scores and compound socores.
# As a result, the sorting dataframe we get by doing NRC-emotion analysis could reflect a more resonable ranking of the movies with good reviews.

# %% [markdown]
# ### General Word Cloud for all reviews

# %%
review=data['Reviews'].str.lower().str.cat(sep=' ')
words=nltk.tokenize.word_tokenize(review)
word_dist = nltk.FreqDist(words)
stopwords = nltk.corpus.stopwords.words('english')
origin_image = imread("Reviews.jpg")
origin_mask = origin_image
words_without_stop = nltk.FreqDist(w for w in words if w not in stopwords) 
wc = WordCloud(stopwords=STOPWORDS,background_color='white',mask=origin_mask, contour_width=3, 
               contour_color='steelblue').generate(" ".join(words_without_stop))
plt.imshow(wc)
fig=plt.gcf()
fig.set_size_inches(15,10)
plt.axis('off')
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """

# %% [markdown]
# ## Text Summarization

# %%
summary_collection = []
for i in range(0,len(data['Reviews'])):
    text = data['Reviews'][i]
    temp_str = "%r"%text
    #print(temp_str)
    striptext = temp_str.replace('",','')
    striptext = striptext.replace("','",' ')
    striptext = striptext.replace('...','')
    striptext = striptext.replace('[','')
    striptext = striptext.replace(']','')
    striptext = striptext.replace("\\",'')
    striptext = striptext.replace("\'",'')
    striptext = striptext.replace("\',",'')
    striptext = striptext.replace(', "',' ')
    striptext = striptext.replace(".,",'.')
    striptext = striptext.replace("\\\\", '')
    summary = gensim.summarization.summarize(striptext, word_count=100) 
    summary_collection.append(summary)
summary_collection = pd.Series(summary_collection)

# %%
new_data = pd.concat([data,summary_collection],axis=1)
new_data.columns = ['Movie_Name','Year','Reviews','Summary']

# %% [markdown]
# ### Get the summary of your favorite movie's reviews!

# %%
name = input('Please type in a movie name between year of 2014 to 2018: ')
print('\n')
try: 
    summ = new_data.loc[new_data['Movie_Name'] == name]['Summary']
    print("Summary:")
    print(list(summ.values)[0])

except:
    print("Uh-oh, seems like the movie is not in our database. Please check your spelling or change a movie name.")
# Out:
# Please type in a movie name between year of 2014 to 2018: Boyhood
#
#
# Summary:
# Richard Linklaters latest feels more like living a life than watching a movie.
# The film ends and the credits come up and you ask the same question that you ask at the end of an evening spent with old, dear friends: where did the time go?,  A marvelous, minimal epic of a movie ,  There isnt anything else quite like "Boyhood" in the history of cinema, although that wouldnt matter one-fifth as much if it werent a moving and memorable viewing experience in the end.
# Richard Linklaters coming-of-age tale is the best movie of the year, a four-star game-changer that earns its place in the cultural time capsule.

# %% [markdown]
# ## Fun time! Get your favorite movie's reviews!

# %% [markdown]
# Let's get your favorite movie's reviews!
#
# Please type in a movie name between year of 2014 to 2018 below:

# %%
name = input('Please type in a movie name between year of 2014 to 2018: ')

# %%
try: 
    summ = new_data.loc[new_data['Movie_Name'] == name]['Summary']
    print("Summary:")
    print(list(summ.values)[0])

except:
    print("Uh-oh, seems like the movie is not in our database. Please check your spelling or change a movie name.")

# %% [markdown]
# # Machine Learning & Word Embedding for Box Office Prediction.ipynb

# %% [markdown]
# ## generate dummy variables & collect features

# %% [markdown]
# ### Import Packages and load data

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from datetime import datetime
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("cleaned_data.csv",index_col='Unnamed: 0')

# %% [markdown]
# the distribution of box_office and log(box_office). We will choose log(box_office) for prediction.

# %%
# using log(box office) for prediction
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
df['box_office'].hist()
plt.title('Box office')

plt.subplot(1,2,2)
np.log(df['box_office']).hist()
plt.title('Log Box office')

plt.show()

# %% [markdown]
# ### generate dummy variables

# %%
# generate dummy variables for rating column
raw_data = pd.concat([df,pd.get_dummies(df['rating'],prefix = 'rating')],axis=1)

# %%
# generate dummy variables for studio column
def get_columns(df_column):
    l = []
    for ele in df_column:
        if ele!='na' and ele!='nan':
            l.extend(ele.split(', '))

    return set([x[1:-1] for x in l])

studio_list = get_columns(raw_data['studio'])
for ele in studio_list:
    raw_data['studio_'+str(ele).strip()]=np.where(raw_data["studio"].str.contains(ele),1,0)

# %%
# generate dummy variables for genre column
genre_list = get_columns(df['genre'])
for ele in genre_list:
    raw_data['genre_'+str(ele)]=np.where(df["genre"].str.contains(ele),1,0)

# %% [markdown]
# ### Caculate days from the earliest movies

# %% [markdown]
# Intuition: Later movies are expected to have larger box office

# %%
# generate 'days_to_000401' column
earliest_date = datetime.strptime(raw_data['time'].min(),"%Y-%m-%d")
print('Earliest date in data:', earliest_date)

temp_list = []
for i in range(len(raw_data)):
    temp_list.append((datetime.strptime(raw_data.iloc[i]['time'],"%Y-%m-%d")-earliest_date).days)
raw_data['days_to_000401'] = temp_list
# Out:
# Earliest date in data: 2000-04-01 00:00:00

# %% [markdown]
# ### Drop columns

# %%
cleaned_date = raw_data.drop(['meter_score','audience_score','name','rating','genre','cast', 'director', 'time','studio'],axis=1)

# %% [markdown]
# ### Train, validation and test split

# %%
from sklearn.model_selection import train_test_split

Y = np.log(cleaned_date['box_office'])
X = cleaned_date.drop(['box_office'],axis=1)
train_X, VT_X, train_Y, VT_Y = train_test_split(X,Y,test_size=0.2)
validation_X, test_X, validation_Y, test_Y = train_test_split(VT_X,VT_Y,test_size=0.5)
train_X.shape,validation_X.shape,test_X.shape,train_Y.shape,validation_Y.shape,test_Y.shape
# Out:
# ((930, 374), (116, 374), (117, 374), (930,), (116,), (117,))

# %% [markdown]
# ## Word Embedding

# %%
from gensim.models import Word2Vec
from nltk import tokenize
from nltk import word_tokenize

# %% [markdown]
# ### Embedding model

# %%
corpus = []
for ele in train_X['movie_synopsis']:
    s = ele.lower()
    corpus.append(word_tokenize(s))

# %%
model = Word2Vec(corpus,size=100, window=5, min_count=1, workers=4)

# %% [markdown]
# ### Transform train/validation/test data

# %%
def transform(x):
    vectors = []
    for ele in x:
        words = word_tokenize(ele.lower())
        total = 0
        vector = np.array([0]*100)
        for ele1 in words:
            try:
                vector = vector+model.wv[ele1]
                total += 1
            except:
                pass
        vector = vector/total*10
        vectors.append(vector)
    return vectors

# %%
# transform training data
word_embedding = pd.DataFrame(transform(train_X['movie_synopsis']),index=train_X.index)
train_X_we = train_X.join(word_embedding)
train_X_we.shape
# Out:
# (930, 474)

# %% [markdown]
# A glimpse of train_X dataset:

# %%
train_X_we.head()
# Out:
#       runtime                                     movie_synopsis  rating_G  \
# 1331       94  Flipping back and forth between the 18th centu...         0
# 286       117  Matthew McConaughey stars in DALLAS BUYERS CLU...         0
# 1663      112  Mild-mannered scientist Bruce Banner has been ...         0
# 1095       87  A family struggles to go on after a devastatin...         0
# 689       127  HIDDEN FIGURES is the incredible untold story ...         0
#
#       rating_NC17  rating_NR  rating_PG  rating_PG-13  rating_R  \
# 1331            0          0          0             0         1
# 286             0          0          0             0         1
# 1663            0          0          0             1         0
# 1095            0          0          0             0         1
# 689             0          0          1             0         0
#
#       studio_Village Roadshow'  studio_'The Weinstein Company'    ...      \
# 1331                         0                               0    ...
# 286                          0                               0    ...
# 1663                         0                               0    ...
# 1095                         0                               0    ...
# 689                          0                               0    ...
#
#             90        91        92        93         94         95        96  \
# 1331  2.337236  5.248883  1.364524  3.724325  11.596282   9.646227 -6.932783
# 286   2.253053  5.209550  1.290010  3.645523  11.455240   9.543464 -6.859856
# 1663  2.389326  5.463634  1.360492  3.845735  12.053989  10.014504 -7.200775
# 1095  2.505030  5.899346  1.367577  4.085153  12.964632  10.759757 -7.736104
# 689   2.073546  5.022348  1.144095  3.412106  10.967946   9.179683 -6.553510
#
#             97        98         99
# 1331  1.411255 -1.431612 -16.268013
# 286   1.372840 -1.338830 -16.039709
# 1663  1.458218 -1.432942 -16.856186
# 1095  1.479191 -1.415573 -18.027786
# 689   1.146452 -1.091280 -15.224534
#
# [5 rows x 474 columns]

# %%
# transform validation data
word_embedding = pd.DataFrame(transform(validation_X['movie_synopsis']),index=validation_X.index)
validation_X_we = validation_X.join(word_embedding)

# transform test data
word_embedding = pd.DataFrame(transform(test_X['movie_synopsis']),index=test_X.index)
test_X_we = test_X.join(word_embedding)

# %% [markdown]
# ### Drop 'movie_synopsis' and rename

# %%
train_X = train_X_we.drop('movie_synopsis',axis=1)
validation_X = validation_X_we.drop('movie_synopsis',axis=1)
test_X = test_X_we.drop('movie_synopsis',axis=1)
train_X.shape,validation_X.shape,test_X.shape
del model

# %% [markdown]
# ## Benchmark model: Linear Regression

# %% [markdown]
# The result of the Linear Regression:

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
OLS_model = LinearRegression()
OLS_model.fit(train_X,train_Y)
print('MSE on training set:', mean_squared_error(OLS_model.predict(train_X),train_Y))
print('MSE on validation set:',mean_squared_error(OLS_model.predict(validation_X),validation_Y))
# Out:
# MSE on training set: 1.0836231700981958
# MSE on validation set: 3.702405009145883

# %% [markdown]
# ## Random Forest and XGBoost

# %% [markdown]
# ### Feature Selection: Lasso

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV

# %%
Lasso_model = Lasso(alpha=0.0002,max_iter=1000000)
Lasso_model.fit(train_X,train_Y)
# train_X.columns[(Lasso_model.coef_==0)][-100:]
# Out:
# Lasso(alpha=0.0002, copy_X=True, fit_intercept=True, max_iter=1000000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %% [markdown]
# Feature numbers that Lasso drop:

# %%
(Lasso_model.coef_==0).sum()
# Out:
# 140

# %% [markdown]
# Rest feature numbers after Lasso:

# %%
drop_list = train_X.columns[(Lasso_model.coef_==0)]
train_X = train_X.drop(drop_list,axis=1)
validation_X = validation_X.drop(drop_list,axis=1)
test_X = test_X.drop(drop_list,axis=1)
train_X.shape[1]
# Out:
# 333

# %% [markdown]
# ### Random Forest

# %% [markdown]
# the result of Random Forest:

# %%
selection_model = GridSearchCV(RandomForestRegressor(),
                             {'n_estimators':[80,160,320],'max_features':[15,30,60,120,200],'max_depth':[3,5,8,16,None]},
                             cv=5)
# %time selection_model.fit(train_X,train_Y)
selection_model.best_estimator_
# Out:
# CPU times: user 4min 20s, sys: 3.16 s, total: 4min 23s
# Wall time: 4min 36s
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=16,
#            max_features=120, max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=320, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
best_rf_model = RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=16,
           max_features=120, max_leaf_nodes=None,
           min_impurity_decrease=0.0, min_impurity_split=None,
           min_samples_leaf=1, min_samples_split=2,
           min_weight_fraction_leaf=0.0, n_estimators=320, n_jobs=None,
           oob_score=False, random_state=None, verbose=0, warm_start=False)
best_rf_model.fit(train_X,train_Y)

print('MSE on training set:', mean_squared_error(best_rf_model.predict(train_X),train_Y))
print('MSE on validation set:',mean_squared_error(best_rf_model.predict(validation_X),validation_Y))
# Out:
# MSE on training set: 0.4163763531748863
# MSE on validation set: 3.6782307866461825

# %%
feature_names = [i for i in train_X.columns]
importances = best_rf_model.feature_importances_
indices = np.argsort(importances)

plt.title('Feature Importances')
plt.barh(range(20), importances[indices][0:20], color='y', align='center')
plt.yticks(range(20),feature_names[0:20])
plt.xlabel('Relative Importance')
plt.show()

# %% [markdown]
# ### XGBoost

# %%
from xgboost import XGBRegressor

# %% [markdown]
# the result of XGBoost:

# %%
XGB_selection_model = GridSearchCV(XGBRegressor(),
                                 {'min_child_weight':[0.25,0.5,1,2,4],'colsample_bytree':[0.5,0.6,0.7,0.8,0.9,1],
                                  'max_depth':[3,5,7,9]},
                                 cv=5)
# %time XGB_selection_model.fit(train_X,train_Y)
XGB_selection_model.best_estimator_
# Out:
# CPU times: user 7min 46s, sys: 6.25 s, total: 7min 52s
# Wall time: 8min 15s
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=4, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
best_XGB = XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
       colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_delta_step=0,
       max_depth=3, min_child_weight=4, missing=None, n_estimators=100,
       n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
       reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
       silent=True, subsample=1)
best_XGB.fit(train_X,train_Y)
mean_squared_error(best_XGB.predict(train_X),train_Y)

print('MSE on training set:', mean_squared_error(best_XGB.predict(train_X),train_Y))
print('MSE on validation set:',mean_squared_error(best_XGB.predict(validation_X),validation_Y))
# Out:
# MSE on training set: 1.6225634876564121
# MSE on validation set: 3.551087928879539

# %% [markdown]
# ## Prediction for Box office

# %% [markdown]
# ### model selection

# %% [markdown]
# According to validation data
# - mean square error of Linear Regression:  3.702405009145883
# - mean square error of Random Forest:  3.6782307866461825
# - mean square error of XGBoost:  3.551087928879539
#
# Therefore Random Forest will be chosen for prediction.
#
# Below is the MSE of the chosen XGB model:

# %%
final_train_X = pd.concat([train_X,validation_X])
final_train_Y = pd.concat([train_Y,validation_Y])
best_XGB.fit(final_train_X,final_train_Y)
mean_squared_error(best_XGB.predict(test_X),test_Y)
# Out:
# 2.291005589375202

# %% [markdown]
# ### Predict Box Office

# %% [markdown]
# The example input for model is illstrated as follows
#
# - First, the raw input should be cleaned by the preprocessing ipynb file (actor_score and director_score could be calculated in that file)
# - Next, the cleaned input should be processed by the ML & WE prediction ipynb file, and will be ready for the model

# %% [markdown]
# example input after data preprocessing:

# %%
# example input after data preprocessing
df.iloc[:1]
# Out:
#           name  meter_score  audience_score rating  \
# 0  Toy Story 3           98              89      G
#
#                                                genre  \
# 0  ['Animation', 'Comedy', 'Kids & Family', 'Scie...
#
#                                                 cast         director  \
# 0  ['Tom Hanks', 'Tim Allen', 'Joan Cusack', 'Ned...  ['Lee Unkrich']
#
#          time                    studio  runtime   box_office  \
# 0  2010-06-18  ['Walt Disney Pictures']      103  414984497.0
#
#                                       movie_synopsis
# 0  "Toy Story 3" welcomes Woody, Buzz and the who...

# %% [markdown]
# example input for model prediction (after preprocessing):

# %%
# example input for model prediction
train_X[:1]
# Out:
#       runtime  rating_G  rating_NC17  rating_NR  rating_PG  rating_PG-13  \
# 1331       94         0            0          0          0             0
#
#       rating_R  studio_'Menemsha'  studio_'Cinema Purgatorio'  \
# 1331         1                  0                           0
#
#       studio_'Wellspring'   ...           41        45        53         64  \
# 1331                    0   ...     3.127892  1.489561  1.540268 -10.764084
#
#             66        75         79        80        81       88
# 1331  3.885459 -4.385925 -16.398596  0.031341 -3.953347  9.97593
#
# [1 rows x 333 columns]

# %% [markdown]
# example prediction by XGBoost model:

# %%
# example prediction by XGBoost model
log_box_office = best_XGB.predict(test_X.iloc[1:2])
box_office = np.exp(log_box_office)
print('predicted box office:\t', box_office[0])
print("real box office:\t",np.exp(test_Y.iloc[1:2]).values[0])
# Out:
# predicted box office:	 1063724.4
# real box office:	 1324335.0000000005

# %%
np.exp(test_Y.iloc[1:2])
# Out:
# 1443    1324335.0
# Name: box_office, dtype: float64

# %% [markdown]
# ## Fun Time! Let's predict movie box office!

# %% [markdown]
# Let's pick an input index from test set and see the model performance!
#
# Input the index number below: (0<=index<=117)

# %%
index = input('please input the index number:')

# %%
print('predicted box office:', best_XGB.predict(test_X.iloc[index]))
print('real box office:',test_Y.iloc[index])
